# %% [markdown]
# <img src="http://www.digitalvidya.com/wp-content/uploads/2013/05/logoa5-300x95.png">

# %% [markdown]
# ## Data Analysis using Python Assignment
# ### Digital Vidya Copyright

# %% [markdown]
# #### Download the IPL dataset from the given link and load it in a dataframe using the following command.
# #### This dataset contains details of each match played in IPL from season 2008 to 2016. Each row represents one match.
# #### Answer the questions based on the dataset.
# #### Please show the code you would use to get to the answer.

# %%
import pandas as pd
import numpy as np

# %%
matches = pd.read_csv(r'C:\Users\balajkm\Desktop\practise\data set\IPL dataset\matches.csv') 
matches
# Out:
#       id  season           city        date                        team1  \
# 0      1    2008      Bangalore  2008-04-18        Kolkata Knight Riders
# 1      2    2008     Chandigarh  2008-04-19          Chennai Super Kings
# 2      3    2008          Delhi  2008-04-19             Rajasthan Royals
# 3      4    2008         Mumbai  2008-04-20               Mumbai Indians
# 4      5    2008        Kolkata  2008-04-20              Deccan Chargers
# 5      6    2008         Jaipur  2008-04-21              Kings XI Punjab
# 6      7    2008      Hyderabad  2008-04-22              Deccan Chargers
# 7      8    2008        Chennai  2008-04-23          Chennai Super Kings
# 8      9    2008      Hyderabad  2008-04-24              Deccan Chargers
# 9     10    2008     Chandigarh  2008-04-25              Kings XI Punjab
# 10    11    2008      Bangalore  2008-04-26  Royal Challengers Bangalore
# 11    12    2008        Chennai  2008-04-26        Kolkata Knight Riders
# 12    13    2008         Mumbai  2008-04-27               Mumbai Indians
# 13    14    2008     Chandigarh  2008-04-27             Delhi Daredevils
# 14    15    2008      Bangalore  2008-04-28          Chennai Super Kings
# 15    16    2008        Kolkata  2008-04-29        Kolkata Knight Riders
# 16    17    2008          Delhi  2008-04-30             Delhi Daredevils
# 17    18    2008      Hyderabad  2008-05-01              Deccan Chargers
# 18    19    2008         Jaipur  2008-05-01             Rajasthan Royals
# 19    20    2008        Chennai  2008-05-02          Chennai Super Kings
# 20    21    2008      Hyderabad  2008-05-25              Deccan Chargers
# 21    22    2008     Chandigarh  2008-05-03              Kings XI Punjab
# 22    23    2008         Mumbai  2008-05-04               Mumbai Indians
# 23    24    2008         Jaipur  2008-05-04          Chennai Super Kings
# 24    25    2008      Bangalore  2008-05-05  Royal Challengers Bangalore
# 25    26    2008        Chennai  2008-05-06          Chennai Super Kings
# 26    27    2008         Mumbai  2008-05-07             Rajasthan Royals
# 27    28    2008          Delhi  2008-05-08             Delhi Daredevils
# 28    29    2008        Kolkata  2008-05-08        Kolkata Knight Riders
# 29    30    2008         Jaipur  2008-05-09              Deccan Chargers
# ..   ...     ...            ...         ...                          ...
# 547  548    2016         Rajkot  2016-05-03                Gujarat Lions
# 548  549    2016        Kolkata  2016-05-04        Kolkata Knight Riders
# 549  550    2016          Delhi  2016-05-05             Delhi Daredevils
# 550  551    2016      Hyderabad  2016-05-06                Gujarat Lions
# 551  552    2016      Bangalore  2016-05-07      Rising Pune Supergiants
# 552  553    2016     Chandigarh  2016-05-07              Kings XI Punjab
# 553  554    2016  Visakhapatnam  2016-05-08          Sunrisers Hyderabad
# 554  555    2016        Kolkata  2016-05-08        Kolkata Knight Riders
Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 552             Delhi Daredevils             Delhi Daredevils         field
# 553               Mumbai Indians               Mumbai Indians         field
# 554                Gujarat Lions                Gujarat Lions         field
# 555              Kings XI Punjab              Kings XI Punjab         field
# 556      Rising Pune Supergiants          Sunrisers Hyderabad           bat
# 557               Mumbai Indians               Mumbai Indians         field
# 558             Delhi Daredevils             Delhi Daredevils         field
# 559              Kings XI Punjab               Mumbai Indians           bat
# 560                Gujarat Lions                Gujarat Lions         field
# 561        Kolkata Knight Riders      Rising Pune Supergiants           bat
# 562          Sunrisers Hyderabad              Kings XI Punjab           bat
# 563             Delhi Daredevils             Delhi Daredevils         field
# 564  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 565      Rising Pune Supergiants      Rising Pune Supergiants         field
# 566              Kings XI Punjab              Kings XI Punjab         field
# 567                Gujarat Lions                Gujarat Lions         field
# 568             Delhi Daredevils             Delhi Daredevils         field
# 569      Rising Pune Supergiants              Kings XI Punjab           bat
# 570                Gujarat Lions                Gujarat Lions         field
# 571          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 572  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 573  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 574        Kolkata Knight Riders        Kolkata Knight Riders         field
# 575          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 576  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 0    normal           0        Kolkata Knight Riders          140
# 1    normal           0          Chennai Super Kings           33
# 2    normal           0             Delhi Daredevils            0
# 3    normal           0  Royal Challengers Bangalore            0
# 4    normal           0        Kolkata Knight Riders            0
# 5    normal           0             Rajasthan Royals            0
# 6    normal           0             Delhi Daredevils            0
# 7    normal           0          Chennai Super Kings            6
# 8    normal           0             Rajasthan Royals            0
# 9    normal           0              Kings XI Punjab           66
# 10   normal           0             Rajasthan Royals            0
# 11   normal           0          Chennai Super Kings            0
# 12   normal           0              Deccan Chargers            0
# 13   normal           0              Kings XI Punjab            0
# 14   normal           0          Chennai Super Kings           13
# 15   normal           0               Mumbai Indians            0
# 16   normal           0             Delhi Daredevils           10
# 17   normal           0              Kings XI Punjab            0
# 18   normal           0             Rajasthan Royals           45
# 19   normal           0             Delhi Daredevils            0
# 20   normal           0  Royal Challengers Bangalore            0
# 21   normal           0              Kings XI Punjab            9
# 22   normal           0               Mumbai Indians           29
# 23   normal           0             Rajasthan Royals            0
# 24   normal           0              Kings XI Punjab            0
# 25   normal           0              Deccan Chargers            0
# 26   normal           0               Mumbai Indians            0
# 27   normal           0          Chennai Super Kings            0
# 28   normal           0        Kolkata Knight Riders            5
# 29   normal           0             Rajasthan Royals            0
# ..      ...         ...                          ...          ...
# 547  normal           0             Delhi Daredevils            0
# 548  normal           0        Kolkata Knight Riders            7
# 549  normal           0      Rising Pune Supergiants            0
# 550  normal           0          Sunrisers Hyderabad            0
# 551  normal           0  Royal Challengers Bangalore            0
# 552  normal           0              Kings XI Punjab            9
# 553  normal           0          Sunrisers Hyderabad           85
# 554  normal           0                Gujarat Lions            0
# 555  normal           0  Royal Challengers Bangalore            1
# 556  normal           0          Sunrisers Hyderabad            4
# 557  normal           0               Mumbai Indians            0
# 558  normal           0             Delhi Daredevils            0
# 559  normal           0              Kings XI Punjab            0
# 560  normal           0  Royal Challengers Bangalore          144
# 561  normal           1        Kolkata Knight Riders            0
# 562  normal           0          Sunrisers Hyderabad            0
# 563  normal           0               Mumbai Indians           80
# 564  normal           0  Royal Challengers Bangalore            0
# 565  normal           1      Rising Pune Supergiants           19
# 566  normal           1  Royal Challengers Bangalore           82
# 567  normal           0                Gujarat Lions            0
# 568  normal           0             Delhi Daredevils            0
# 569  normal           0      Rising Pune Supergiants            0
# 570  normal           0                Gujarat Lions            0
# 571  normal           0        Kolkata Knight Riders           22
# 572  normal           0  Royal Challengers Bangalore            0
# 573  normal           0  Royal Challengers Bangalore            0
# 574  normal           0          Sunrisers Hyderabad           22
# 575  normal           0          Sunrisers Hyderabad            0
# 576  normal           0          Sunrisers Hyderabad            8
#
#      win_by_wickets player_of_match  \
# 0                 0     BB McCullum
# 1                 0      MEK Hussey
# 2                 9     MF Maharoof
# 3                 5      MV Boucher
# 4                 5       DJ Hussey
Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...                 S Ravi
# 554                                       Eden Gardens              M Erasmus
# 555  Punjab Cricket Association IS Bindra Stadium, ...           AK Chaudhary
# 556  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...            CB Gaffaney
# 557                              M Chinnaswamy Stadium            AY Dandekar
# 558          Rajiv Gandhi International Stadium, Uppal             K Bharatan
# 559  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...        HDPK Dharmasena
# 560                              M Chinnaswamy Stadium            AY Dandekar
# 561                                       Eden Gardens         A Nand Kishore
# 562  Punjab Cricket Association IS Bindra Stadium, ...  KN Ananthapadmanabhan
# 563  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...            Nitin Menon
# 564                                       Eden Gardens            CB Gaffaney
# 565  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...            Nitin Menon
# 566                              M Chinnaswamy Stadium  KN Ananthapadmanabhan
# 567                                         Green Park           AK Chaudhary
# 568   Shaheed Veer Narayan Singh International Stadium         A Nand Kishore
# 569  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...        HDPK Dharmasena
# 570                                         Green Park           AK Chaudhary
# 571                                       Eden Gardens  KN Ananthapadmanabhan
# 572   Shaheed Veer Narayan Singh International Stadium         A Nand Kishore
# 573                              M Chinnaswamy Stadium           AK Chaudhary
# 574                                   Feroz Shah Kotla              M Erasmus
# 575                                   Feroz Shah Kotla              M Erasmus
# 576                              M Chinnaswamy Stadium        HDPK Dharmasena
#
#              umpire2  umpire3
# 0        RE Koertzen      NaN
# 1         SL Shastri      NaN
# 2     GA Pratapkumar      NaN
# 3          DJ Harper      NaN
# 4        K Hariharan      NaN
# 5          RB Tiffin      NaN
# 6          AM Saheba      NaN
# 7     GA Pratapkumar      NaN
# 8          MR Benson      NaN
# 9          AM Saheba      NaN
# 10         IL Howell      NaN
# 11    AV Jayaprakash      NaN
# 12        SL Shastri      NaN
# 13         I Shivram      NaN
# 14         RB Tiffin      NaN
# 15    AV Jayaprakash      NaN
# 16         I Shivram      NaN
# 17         RB Tiffin      NaN
# 18    GA Pratapkumar      NaN
# 19       K Hariharan      NaN
# 20       RE Koertzen      NaN
# 21         I Shivram      NaN
# 22       RE Koertzen      NaN
# 23    AV Jayaprakash      NaN
# 24       BR Doctrove      NaN
# 25         RB Tiffin      NaN
# 26       RE Koertzen      NaN
# 27         RB Tiffin      NaN
# 28         IL Howell      NaN
# 29         AM Saheba      NaN
# ..               ...      ...
# 547     BNJ Oxenford      NaN
# 548  HDPK Dharmasena      NaN
# 549        RJ Tucker      NaN
# 550           S Ravi      NaN
# 551     BNJ Oxenford      NaN
# 552        CK Nandan      NaN
# 553    C Shamshuddin      NaN
# 554        RJ Tucker      NaN
# 555  HDPK Dharmasena      NaN
# 556        VK Sharma      NaN
# 557    C Shamshuddin      NaN
# 558        M Erasmus      NaN
# 559        CK Nandan      NaN
# 560        VK Sharma      NaN
# 561     BNJ Oxenford      NaN
# 562        M Erasmus      NaN
# 563        CK Nandan      NaN
# 564   A Nand Kishore      NaN
# 565    C Shamshuddin      NaN
# 566        M Erasmus      NaN
# 567        CK Nandan      NaN
# 568     BNJ Oxenford      NaN
# 569      Nitin Menon      NaN
# 570        CK Nandan      NaN
# 571        M Erasmus      NaN
# 572     BNJ Oxenford      NaN
# 573  HDPK Dharmasena      NaN
# 574    C Shamshuddin      NaN
# 575        CK Nandan      NaN
# 576     BNJ Oxenford      NaN
#
# [577 rows x 18 columns]

# %%
# 1. What is the easiest way to view the details of the last match of the dataset?
matches.tail(n=1)
# Out:
#       id  season       city        date                team1  \
# 576  577    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2          toss_winner toss_decision  result  \
# 576  Royal Challengers Bangalore  Sunrisers Hyderabad           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 576           0  Sunrisers Hyderabad            8               0
#
#     player_of_match                  venue          umpire1       umpire2  \
# 576     BCJ Cutting  M Chinnaswamy Stadium  HDPK Dharmasena  BNJ Oxenford
#
#      umpire3
# 576      NaN

# %%
# 2. Create a slice of this dataframe to only show the details from index 517 to 576 and columns id, season, city 
#and date. Print the output.

c=matches[517:567]
c.groupby(['id','season','city','date']).groups
# Out:
# {(518, 2016, 'Mumbai', '2016-04-09'): Int64Index([517], dtype='int64'),
#  (519, 2016, 'Kolkata', '2016-04-10'): Int64Index([518], dtype='int64'),
#  (520, 2016, 'Chandigarh', '2016-04-11'): Int64Index([519], dtype='int64'),
#  (521, 2016, 'Bangalore', '2016-04-12'): Int64Index([520], dtype='int64'),
#  (522, 2016, 'Kolkata', '2016-04-13'): Int64Index([521], dtype='int64'),
#  (523, 2016, 'Rajkot', '2016-04-14'): Int64Index([522], dtype='int64'),
#  (524, 2016, 'Delhi', '2016-04-15'): Int64Index([523], dtype='int64'),
#  (525, 2016, 'Hyderabad', '2016-04-16'): Int64Index([524], dtype='int64'),
#  (526, 2016, 'Mumbai', '2016-04-16'): Int64Index([525], dtype='int64'),
#  (527, 2016, 'Chandigarh', '2016-04-17'): Int64Index([526], dtype='int64'),
#  (528, 2016, 'Bangalore', '2016-04-17'): Int64Index([527], dtype='int64'),
#  (529, 2016, 'Hyderabad', '2016-04-18'): Int64Index([528], dtype='int64'),
#  (530, 2016, 'Chandigarh', '2016-04-19'): Int64Index([529], dtype='int64'),
#  (531, 2016, 'Mumbai', '2016-04-20'): Int64Index([530], dtype='int64'),
#  (532, 2016, 'Rajkot', '2016-04-21'): Int64Index([531], dtype='int64'),
#  (533, 2016, 'Pune', '2016-04-22'): Int64Index([532], dtype='int64'),
#  (534, 2016, 'Delhi', '2016-04-23'): Int64Index([533], dtype='int64'),
#  (535, 2016, 'Hyderabad', '2016-04-23'): Int64Index([534], dtype='int64'),
#  (536, 2016, 'Rajkot', '2016-04-24'): Int64Index([535], dtype='int64'),
#  (537, 2016, 'Pune', '2016-04-24'): Int64Index([536], dtype='int64'),
#  (538, 2016, 'Chandigarh', '2016-04-25'): Int64Index([537], dtype='int64'),
#  (539, 2016, 'Hyderabad', '2016-04-26'): Int64Index([538], dtype='int64'),
#  (540, 2016, 'Delhi', '2016-04-27'): Int64Index([539], dtype='int64'),
#  (541, 2016, 'Mumbai', '2016-04-28'): Int64Index([540], dtype='int64'),
#  (542, 2016, 'Pune', '2016-04-29'): Int64Index([541], dtype='int64'),
#  (543, 2016, 'Delhi', '2016-04-30'): Int64Index([542], dtype='int64'),
#  (544, 2016, 'Hyderabad', '2016-04-30'): Int64Index([543], dtype='int64'),
#  (545, 2016, 'Rajkot', '2016-05-01'): Int64Index([544], dtype='int64'),
#  (546, 2016, 'Pune', '2016-05-01'): Int64Index([545], dtype='int64'),
#  (547, 2016, 'Bangalore', '2016-05-02'): Int64Index([546], dtype='int64'),
#  (548, 2016, 'Rajkot', '2016-05-03'): Int64Index([547], dtype='int64'),
#  (549, 2016, 'Kolkata', '2016-05-04'): Int64Index([548], dtype='int64'),
#  (550, 2016, 'Delhi', '2016-05-05'): Int64Index([549], dtype='int64'),
#  (551, 2016, 'Hyderabad', '2016-05-06'): Int64Index([550], dtype='int64'),
#  (552, 2016, 'Bangalore', '2016-05-07'): Int64Index([551], dtype='int64'),
#  (553, 2016, 'Chandigarh', '2016-05-07'): Int64Index([552], dtype='int64'),
#  (554, 2016, 'Visakhapatnam', '2016-05-08'): Int64Index([553], dtype='int64'),
#  (555, 2016, 'Kolkata', '2016-05-08'): Int64Index([554], dtype='int64'),
#  (556, 2016, 'Chandigarh', '2016-05-09'): Int64Index([555], dtype='int64'),
#  (557, 2016, 'Visakhapatnam', '2016-05-10'): Int64Index([556], dtype='int64'),
#  (558, 2016, 'Bangalore', '2016-05-11'): Int64Index([557], dtype='int64'),
#  (559, 2016, 'Hyderabad', '2016-05-12'): Int64Index([558], dtype='int64'),
#  (560, 2016, 'Visakhapatnam', '2016-05-13'): Int64Index([559], dtype='int64'),
#  (561, 2016, 'Bangalore', '2016-05-14'): Int64Index([560], dtype='int64'),
#  (562, 2016, 'Kolkata', '2016-05-14'): Int64Index([561], dtype='int64'),
#  (563, 2016, 'Chandigarh', '2016-05-15'): Int64Index([562], dtype='int64'),
#  (564, 2016, 'Visakhapatnam', '2016-05-15'): Int64Index([563], dtype='int64'),
#  (565, 2016, 'Kolkata', '2016-05-16'): Int64Index([564], dtype='int64'),
#  (566, 2016, 'Visakhapatnam', '2016-05-17'): Int64Index([565], dtype='int64'),
#  (567, 2016, 'Bangalore', '2016-05-18'): Int64Index([566], dtype='int64')}

# %%
# 3. The final match of the season 2011 is at the index 247, on what date was the match played?
a=matches[247:248]
a.groupby('date').groups
# Out:
# {'2011-05-28': Int64Index([247], dtype='int64')}

# %%
# 4. Create a new dataframe called matches_compact which contains only the id, season, date and winner. 
#What is the shape of the matches_compact?
matches_compact=pd.DataFrame(matches,columns=(['id','season','date','winner']))
matches_compact
matches_compact.shape
# Out:
# (577, 4)

# %%
# 5. How many matches were played in the year 2010? 
matches.groupby('season').sum()
# Out:
#            id  dl_applied  win_by_runs  win_by_wickets  umpire3
# season
# 2008     1711           2          705             221      0.0
# 2009     4959           3          764             180      0.0
# 2010     8730           0          976             190      0.0
# 2011    15476           3         1098             265      0.0
# 2012    21127           0          960             241      0.0
# 2013    27398           0         1241             227      0.0
# 2014    25710           1          644             225      0.0
# 2015    28792           2          850             148      0.0
# 2016    32850           4          676             244      0.0

# %%
# 6. How will you find the highest margin of runs by which any team won the match in matches so far? 
#Which team was it and by how many runs did it win?
a=matches.groupby(['winner']).win_by_runs.max()
print(a)
# Out:
# winner
# Chennai Super Kings             97
# Deccan Chargers                 82
# Delhi Daredevils                67
# Gujarat Lions                    1
# Kings XI Punjab                111
# Kochi Tuskers Kerala            17
# Kolkata Knight Riders          140
# Mumbai Indians                  98
# Pune Warriors                   38
# Rajasthan Royals               105
# Rising Pune Supergiants         34
# Royal Challengers Bangalore    144
# Sunrisers Hyderabad             85
# Name: win_by_runs, dtype: int64

# %%
# 7. Here is a dictionary of short names for all the team names in the dataset. Create a new dataframe called 
# matches_alias by replacing names in all the columns with long team names.
team_names = {'Kolkata Knight Riders': 'KKR', 
              'Chennai Super Kings': 'CSK', 
              'Rajasthan Royals' : 'RR',
               'Mumbai Indians' : 'MI', 
              'Deccan Chargers' : 'DC', 
              'Kings XI Punjab' : 'KIXP',
               'Royal Challengers Bangalore' : 'RCB', 
              'Delhi Daredevils' : 'DD',
              'Kochi Tuskers Kerala' : 'KTK', 
              'Pune Warriors' : 'PW', 
              'Sunrisers Hyderabad' : 'SRH',
              'Rising Pune Supergiants' : 'RPS', 
              'Gujarat Lions' : 'GL'}

team_names
matches_alias=pd.DataFrame([team_names])
matches_alias.replace('csk','chennai super kings')
matches_alias
# Out:
#   Chennai Super Kings Deccan Chargers Delhi Daredevils Gujarat Lions  \
# 0                 CSK              DC               DD            GL
#
#   Kings XI Punjab Kochi Tuskers Kerala Kolkata Knight Riders Mumbai Indians  \
# 0            KIXP                  KTK                   KKR             MI
#
#   Pune Warriors Rajasthan Royals Rising Pune Supergiants  \
# 0            PW               RR                     RPS
#
#   Royal Challengers Bangalore Sunrisers Hyderabad
# 0                         RCB                 SRH

# %%
# 8. Find out in which stadium the maximum number of matches have been played and in which stadium minimum? 
# What is the highest and the lowest number? Show the code.
x=matches.venue.value_counts()
x
# Out:
# M Chinnaswamy Stadium                                   58
# Eden Gardens                                            54
# Feroz Shah Kotla                                        53
# Wankhede Stadium                                        49
# MA Chidambaram Stadium, Chepauk                         48
# Rajiv Gandhi International Stadium, Uppal               41
# Punjab Cricket Association Stadium, Mohali              35
# Sawai Mansingh Stadium                                  33
# Subrata Roy Sahara Stadium                              17
# Dr DY Patil Sports Academy                              17
# Kingsmead                                               15
# SuperSport Park                                         12
# Sardar Patel Stadium, Motera                            12
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium     11
# Brabourne Stadium                                       11
# Himachal Pradesh Cricket Association Stadium             9
# Maharashtra Cricket Association Stadium                  8
# New Wanderers Stadium                                    8
# Dubai International Cricket Stadium                      7
# St George's Park                                         7
# Sheikh Zayed Stadium                                     7
# Barabati Stadium                                         7
# JSCA International Stadium Complex                       7
# Punjab Cricket Association IS Bindra Stadium, Mohali     7
# Newlands                                                 7
# Shaheed Veer Narayan Singh International Stadium         6
# Sharjah Cricket Stadium                                  6
# Saurashtra Cricket Association Stadium                   5
# Nehru Stadium                                            5
# Vidarbha Cricket Association Stadium, Jamtha             3
# De Beers Diamond Oval                                    3
# Buffalo Park                                             3
# Green Park                                               2
# Holkar Cricket Stadium                                   2
# OUTsurance Oval                                          2
# Name: venue, dtype: int64

# %%
# 9. The following dataframe contains large blocks of NaNs. 
# Fill the NAs with mean only for 2 or less consecutive values of NAs. 
# Refer to the documentation of fillna() to find out the parameter you would use to fill only a certail number of NAs.
# The resulting dataframe should look like df_filled shown below.

df = pd.DataFrame({'val1':[4,np.nan,7,np.nan,np.nan,9,5, np.nan , 1,9,np.nan, np.nan,np.nan, 5, np.nan], 
                    'val2': [ np.nan, 5,7,np.nan, np.nan,8,3,np.nan, 4,np.nan, np.nan, np.nan,np.nan,21,np.nan]})

d = {'val1': {0: 4.0,1: 5.7142857142857144,2: 7.0,3: 5.7142857142857144,4: np.nan,5: 9.0,6: 5.0,7: np.nan,8: 1.0,9: 9.0,10: np.nan,11: np.nan,12: np.nan,13: 5.0,14: np.nan},
'val2': {0: 8.0,1: 5.0,2: 7.0,3: 8.0,4: np.nan,5: 8.0,6: 3.0,7: np.nan,8: 4.0,9: np.nan,10: np.nan,11: np.nan,12: np.nan,13: 21.0,14: np.nan}}

df_filled = pd.DataFrame(d)

# %%
df = pd.DataFrame({'val1':[4,np.nan,7,np.nan,np.nan,9,5, np.nan , 1,9,np.nan, np.nan,np.nan, 5, np.nan], 
                    'val2': [ np.nan, 5,7,np.nan, np.nan,8,3,np.nan, 4,np.nan, np.nan, np.nan,np.nan,21,np.nan]})
c=df.mean()
c
df.fillna(c,limit=2)
# Out:
#         val1  val2
# 0   4.000000   8.0
# 1   5.714286   5.0
# 2   7.000000   7.0
# 3   5.714286   8.0
# 4        NaN   NaN
# 5   9.000000   8.0
# 6   5.000000   3.0
# 7        NaN   NaN
# 8   1.000000   4.0
# 9   9.000000   NaN
# 10       NaN   NaN
# 11       NaN   NaN
# 12       NaN   NaN
# 13  5.000000  21.0
# 14       NaN   NaN

# %%
# 10. For the dataframe given below, 
# Convert the NaN values to zero
# Add a row called diff with the difference between minimum and maximum value in each column. Try solving it using lambda function
# Add a column called diff with the difference between minimum and maximum value in each row. 
# The final df should look like df_final shown below

df = pd.DataFrame({'val1':[9,15,71,9,5], 'val2': [8,31,10, 14,np.nan]})

df_final = pd.DataFrame({'diff': {0: 1.0, 1: 16.0, 2: 61.0, 3: 5.0, 4: 5.0, 'diff': 35.0},
 'val1': {0: 9.0, 1: 15.0, 2: 71.0, 3: 9.0, 4: 5.0, 'diff': 66.0},
 'val2': {0: 8.0, 1: 31.0, 2: 10.0, 3: 14.0, 4: 0.0, 'diff': 31.0}})

df_final
# Out:
#       diff  val1  val2
# 0      1.0   9.0   8.0
# 1     16.0  15.0  31.0
# 2     61.0  71.0  10.0
# 3      5.0   9.0  14.0
# 4      5.0   5.0   0.0
# diff  35.0  66.0  31.0

# %%
a=pd.DataFrame({'val1':[9,15,71,9,np.nan], 'val2': [8,31,10, 14,np.nan]})

a.loc['diff']=a.max()-a.min()
a['diff']=(a['val1']-a['val2'])
a.fillna(0)
# Out:
#       val1  val2  diff
# 0      9.0   8.0   1.0
# 1     15.0  31.0 -16.0
# 2     71.0  10.0  61.0
# 3      9.0  14.0  -5.0
# 4      0.0   0.0   0.0
# diff  62.0  23.0  39.0
